# %%
from lib.dedalus_Plot import Plot
folder="mountain4"
Plotter=Plot(save_dir="/scratch/zb2113/DedalusData/"+folder)
Plotter.get_sim_time()
print(Plotter.sim_time)
Plotter.plot_all_snapshots('M', output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder,levelnum=100)
Plotter.plot_all_snapshots('ux', output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder ,levelnum=100)
Plotter.plot_all_snapshots('uz', output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder,levelnum=100)
Plotter.animate('ux',use_existing_pics=True,output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder)
Plotter.animate('uz',use_existing_pics=True,output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder)
Plotter.animate('M',use_existing_pics=True,output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder)
# Out:
# ['scales', 'tasks']
# Scale keys: ['constant', 'iteration', 'sim_time', 'timestep', 'wall_time', 'write_number', 'x_hash_c08c10aa2917d4e78da4fcf3e0119c712fb382ba', 'z_hash_6494cb26dbe3c4d68ad5364b5b16e4867673a25c']
# Task keys: ['Fsponge', 'M', 'p', 'tau_M1', 'tau_M2', 'tau_p', 'tau_u1', 'tau_u2', 'time', 'u', 'u square', 'ux', 'uz']
# [0.0, 5.000000000000082, 10.000000000000153, 14.999999999999158, 20.000000000001005, 25.000000000003563, 30.00000000000612, 35.00000000000441, 39.999999999999865, 44.99999999999532, 49.99999999999077, 54.99999999998622, 59.999999999981675, 64.99999999997713, 69.99999999997259, 74.99999999996804, 79.99999999996349, 84.99999999995894, 89.9999999999544, 94.99999999994985, 99.9999999999453, 104.99999999994075, 109.99999999993621, 114.99999999993166, 119.99999999992711, 124.99999999992257, 129.99999999991803, 134.99999999991348, 139.99999999990894, 144.9999999999044, 149.99999999989984]
# 5.400393038479247e-07
# 4.999953005653872
# -0.014970781050837751
# 0.015031697871588218
# -0.007478000972005978
# 0.0052235263780604484
# Using existing pictures from /home/zb2113/Dedalus-Postanalysis/2D/mountain4/ux
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 9
#       7 Plotter.plot_all_snapshots('ux', output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder ,levelnum=100)
#       8 Plotter.plot_all_snapshots('uz', output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder,levelnum=100)
# ----> 9 Plotter.animate('ux',use_existing_pics=True,output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder)
#      10 Plotter.animate('uz',use_existing_pics=True,output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder)
#      11 Plotter.animate('M',use_existing_pics=True,output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder)
#
# File ~/Research-Dedalus/2d-AR=64/lib/dedalus_Plot.py:181, in Plot.animate(self, task_name, output_dir, fps, use_existing_pics, output_type)
#     179 if use_existing_pics and existing_pics:
#     180     print(f"Using existing pictures from {pics_folder}")
# --> 181     self.create_animation_from_pics(existing_pics, output_file, fps, output_type)
#     182 else:
#     183     print("Generating new animation from data")
#
# File ~/Research-Dedalus/2d-AR=64/lib/dedalus_Plot.py:199, in Plot.create_animation_from_pics(self, pic_files, output_file, fps, output_type)
#     196 images = [Image.open(f) for f in pic_files]
#     198 if output_type.lower() == 'gif':
# --> 199     images[0].save(output_file, save_all=True, append_images=images[1:],
#     200                    duration=1000/fps, loop=0)
#     202 elif output_type.lower() == 'mp4':
#     203     import moviepy.editor as mpy
#
# File /share/apps/anaconda3/2024.02/lib/python3.11/site-packages/PIL/Image.py:2439, in Image.save(self, fp, format, **params)
#    2436         fp = builtins.open(filename, "w+b")
#    2438 try:
# -> 2439     save_handler(self, fp, filename)
#    2440 except Exception:
#    2441     if open_fp:
#
# File /share/apps/anaconda3/2024.02/lib/python3.11/site-packages/PIL/GifImagePlugin.py:704, in _save_all(im, fp, filename)
#     703 def _save_all(im, fp, filename):
# --> 704     _save(im, fp, filename, save_all=True)
#
# File /share/apps/anaconda3/2024.02/lib/python3.11/site-packages/PIL/GifImagePlugin.py:715, in _save(im, fp, filename, save_all)
#     712     palette = None
#     713     im.encoderinfo.setdefault("optimize", True)
# --> 715 if not save_all or not _write_multiple_frames(im, fp, palette):
#     716     _write_single_frame(im, fp, palette)
#     718 fp.write(b";")  # end of file
#
# File /share/apps/anaconda3/2024.02/lib/python3.11/site-packages/PIL/GifImagePlugin.py:671, in _write_multiple_frames(im, fp, palette)
#     669                     delta = delta_l
#     670                 mask = ImageMath.eval("convert(im * 255, '1')", im=delta)
# --> 671             diff_frame.paste(fill, mask=ImageOps.invert(mask))
#     672 else:
#     673     bbox = None
#
# File /share/apps/anaconda3/2024.02/lib/python3.11/site-packages/PIL/Image.py:1738, in Image.paste(self, im, box, mask)
#    1736 if mask:
#    1737     mask.load()
# -> 1738     self.im.paste(im, box, mask.im)
#    1739 else:
#    1740     self.im.paste(im, box)
#
# ValueError: images do not match
