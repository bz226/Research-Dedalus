# %%
from lib.dedalus_Plot import Plot
folder="mountain3"
Plotter=Plot(save_dir="/scratch/zb2113/DedalusData/"+folder)
Plotter.get_sim_time()
print(Plotter.sim_time)
Plotter.plot_all_snapshots('M', output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder,levelnum=30,figure_size=(10,5))
Plotter.plot_all_snapshots('ux', output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder ,levelnum=30)
Plotter.plot_all_snapshots('uz', output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder,levelnum=30)
Plotter.animate('ux',use_existing_pics=True,output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder)
Plotter.animate('uz',use_existing_pics=True,output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder)
Plotter.animate('M',use_existing_pics=True,output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder)
# Out:
# Traceback (most recent call last):
#
#   File /ext3/miniconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3508 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[2], line 1
#     from lib.dedalus_Plot import Plot
#
#   File ~/Research-Dedalus/2d-AR=64/lib/dedalus_Plot.py:172
#     if scaling = True:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
from lib.dedalus_Plot import Plot
folder="mountain3"
Plotter=Plot(save_dir="/scratch/zb2113/DedalusData/"+folder)
Plotter.get_sim_time()
print(Plotter.sim_time)
Plotter.plot_all_snapshots('M', output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder,levelnum=30,figure_size=(10,5),)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 from lib.dedalus_Plot import Plot
#       2 folder="mountain3"
# ----> 3 Plotter=Plot(save_dir="/scratch/zb2113/DedalusData/"+folder,handler='maskcheck')
#       4 Plotter.get_sim_time()
#       5 print(Plotter.sim_time)
#
# File ~/Research-Dedalus/2d-AR=64/lib/dedalus_Plot.py:27, in Plot.__init__(self, save_dir, handler, dimension)
#      25 self.dimension = dimension
#      26 self.sim_time = None
# ---> 27 self.get_grid_data()
#      28 self.get_sim_time()
#      29 # Cache for loaded data
#
# File ~/Research-Dedalus/2d-AR=64/lib/dedalus_Plot.py:43, in Plot.get_grid_data(self)
#      41 def get_grid_data(self):
#      42     # Get grid information from the last file (assumes grid is constant in time)
# ---> 43     file = self.file_paths[-1]
#      44     with h5py.File(file, mode='r') as file_obj:
#      45         # Print keys for debugging purposes
#      46         print("File keys:", list(file_obj.keys()))
#
# IndexError: list index out of range
