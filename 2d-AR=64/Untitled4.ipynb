# %%
from lib.dedalus_Plot import Plot
folder="mountain3"
Plotter=Plot(save_dir="/scratch/zb2113/DedalusData/"+folder)
Plotter.get_sim_time()
print(Plotter.sim_time)
Plotter.plot_all_snapshots('M', output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder,levelnum=30,figure_size=(10,5))
Plotter.plot_all_snapshots('ux', output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder ,levelnum=30)
Plotter.plot_all_snapshots('uz', output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder,levelnum=30)
Plotter.animate('ux',use_existing_pics=True,output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder)
Plotter.animate('uz',use_existing_pics=True,output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder)
Plotter.animate('M',use_existing_pics=True,output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder)
# Out:
# ['scales', 'tasks']
# Scale keys: ['constant', 'iteration', 'sim_time', 'timestep', 'wall_time', 'write_number', 'x_hash_cd7d67f5db6771271d03274a051ff746cf667007', 'z_hash_6494cb26dbe3c4d68ad5364b5b16e4867673a25c']
# Task keys: ['Fsponge', 'M', 'dxM', 'dxdxM', 'dxuz', 'dzM', 'dzdzM', 'p', 'tau_M1', 'tau_M2', 'tau_p', 'tau_u1', 'tau_u2', 'time', 'u', 'u square', 'ux', 'uz']
# [0.0, 0.25000000000000017, 0.5000000000000003, 0.749999999999995, 0.9999999999999897, 1.2499999999999845, 1.4999999999999791, 1.7499999999999738, 1.9999999999999685, 2.249999999999963, 2.499999999999958, 2.7499999999999525, 2.999999999999947, 3.249999999999942]
# Loading data...
# Calculating global min/max...
# Creating figure...
# Processing 14 snapshots...
# Progress: 10/14 frames processed
# Finished processing all snapshots!
# Loading data...
# Calculating global min/max...
# Creating figure...
# Processing 14 snapshots...
# Progress: 10/14 frames processed
# Finished processing all snapshots!
# Loading data...
# Calculating global min/max...
# Creating figure...
# Processing 14 snapshots...
# Progress: 10/14 frames processed
# Finished processing all snapshots!
# Using existing pictures from /home/zb2113/Dedalus-Postanalysis/2D/mountain3/ux
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 9
#       7 Plotter.plot_all_snapshots('ux', output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder ,levelnum=30)
#       8 Plotter.plot_all_snapshots('uz', output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder,levelnum=30)
# ----> 9 Plotter.animate('ux',use_existing_pics=True,output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder)
#      10 Plotter.animate('uz',use_existing_pics=True,output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder)
#      11 Plotter.animate('M',use_existing_pics=True,output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder)
#
# File ~/Research-Dedalus/2d-AR=64/lib/dedalus_Plot.py:197, in Plot.animate(self, task_name, output_dir, fps, use_existing_pics, output_type)
#     195 if use_existing_pics and existing_pics:
#     196     print(f"Using existing pictures from {pics_folder}")
# --> 197     self.create_animation_from_pics(existing_pics, output_file, fps, output_type)
#     198 else:
#     199     print("Generating new animation from data")
#
# File ~/Research-Dedalus/2d-AR=64/lib/dedalus_Plot.py:207, in Plot.create_animation_from_pics(self, pic_files, output_file, fps, output_type)
#     204 images = [Image.open(f) for f in pic_files]
#     206 if output_type.lower() == 'gif':
# --> 207     images[0].save(output_file, save_all=True, append_images=images[1:],
#     208                    duration=1000/fps, loop=0)
#     209 elif output_type.lower() == 'mp4':
#     210     import moviepy.editor as mpy
#
# File /share/apps/anaconda3/2024.02/lib/python3.11/site-packages/PIL/Image.py:2439, in Image.save(self, fp, format, **params)
#    2436         fp = builtins.open(filename, "w+b")
#    2438 try:
# -> 2439     save_handler(self, fp, filename)
#    2440 except Exception:
#    2441     if open_fp:
#
# File /share/apps/anaconda3/2024.02/lib/python3.11/site-packages/PIL/GifImagePlugin.py:704, in _save_all(im, fp, filename)
#     703 def _save_all(im, fp, filename):
# --> 704     _save(im, fp, filename, save_all=True)
#
# File /share/apps/anaconda3/2024.02/lib/python3.11/site-packages/PIL/GifImagePlugin.py:715, in _save(im, fp, filename, save_all)
#     712     palette = None
#     713     im.encoderinfo.setdefault("optimize", True)
# --> 715 if not save_all or not _write_multiple_frames(im, fp, palette):
#     716     _write_single_frame(im, fp, palette)
#     718 fp.write(b";")  # end of file
#
# File /share/apps/anaconda3/2024.02/lib/python3.11/site-packages/PIL/GifImagePlugin.py:671, in _write_multiple_frames(im, fp, palette)
#     669                     delta = delta_l
#     670                 mask = ImageMath.eval("convert(im * 255, '1')", im=delta)
# --> 671             diff_frame.paste(fill, mask=ImageOps.invert(mask))
#     672 else:
#     673     bbox = None
#
# File /share/apps/anaconda3/2024.02/lib/python3.11/site-packages/PIL/Image.py:1738, in Image.paste(self, im, box, mask)
#    1736 if mask:
#    1737     mask.load()
# -> 1738     self.im.paste(im, box, mask.im)
#    1739 else:
#    1740     self.im.paste(im, box)
#
# ValueError: images do not match

# %%
from lib.dedalus_Plot import Plot
folder="mountain3"
Plotter=Plot(save_dir="/scratch/zb2113/DedalusData/"+folder,handler='maskcheck')
Plotter.get_sim_time()
print(Plotter.sim_time)
Plotter.plot_all_snapshots('mask', output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder,levelnum=100,figure_size=(10,5))
# Out:
# ['scales', 'tasks']
# Scale keys: ['constant', 'iteration', 'sim_time', 'timestep', 'wall_time', 'write_number', 'x_hash_b9a233d85ffc53b3fab968b8031c8e1e7f8a755a', 'z_hash_3c859c36a9c2f295aaab1dec0ec24d51221a3714']
# Task keys: ['mask', 'sponge']
# [0.0]
# Loading data...
# Calculating global min/max...
# Creating figure...
# Processing 1 snapshots...
# Finished processing all snapshots!
