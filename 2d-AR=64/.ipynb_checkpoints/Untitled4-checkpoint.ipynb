# Loading data...
# Calculating global min/max...
# Creating figure...
# Processing 100 snapshots...
# Progress: 10/100 frames processed
# Progress: 20/100 frames processed
# Progress: 30/100 frames processed
# Progress: 40/100 frames processed
# Progress: 50/100 frames processed
# Progress: 60/100 frames processed
# Progress: 70/100 frames processed
# Progress: 80/100 frames processed
# Progress: 90/100 frames processed
# Progress: 100/100 frames processed
# Finished processing all snapshots!
# Loading data...
# Calculating global min/max...
# Creating figure...
# Processing 100 snapshots...
# Progress: 10/100 frames processed
# Progress: 20/100 frames processed
# Progress: 30/100 frames processed
# Progress: 40/100 frames processed
# Progress: 50/100 frames processed
# Progress: 60/100 frames processed
# Progress: 70/100 frames processed
# Progress: 80/100 frames processed
# Progress: 90/100 frames processed
# Progress: 100/100 frames processed
# Finished processing all snapshots!
# Loading data...
# Calculating global min/max...
# Creating figure...
# Processing 100 snapshots...
# Progress: 10/100 frames processed
# Progress: 20/100 frames processed
# Progress: 30/100 frames processed
# Progress: 40/100 frames processed
# Progress: 50/100 frames processed
# Progress: 60/100 frames processed
# Progress: 70/100 frames processed
# Progress: 80/100 frames processed
# Progress: 90/100 frames processed
# Progress: 100/100 frames processed
# Finished processing all snapshots!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       7 Plotter.plot_all_snapshots('ux', output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder ,levelnum=100)
#       8 Plotter.plot_all_snapshots('uz', output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder,levelnum=100)
# ----> 9 Plotter.animate('ux',use_existing_pics=True,output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder)
#      10 Plotter.animate('uz',use_existing_pics=True,output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder)
#      11 Plotter.animate('M',use_existing_pics=True,output_dir="/home/zb2113/Dedalus-Postanalysis/2D/"+folder)
#
# File ~/Research-Dedalus/2d-AR=64/lib/dedalus_Plot.py:190, in Plot.animate(self, task_name, output_dir, fps, use_existing_pics, output_type)
#     185     output_file = os.path.join(output_dir, f'{task_name}_animation.{output_type}')
#     186     pics_folder = os.path.join(output_dir, task_name)
# --> 190 existing_pics = sorted(glob.glob(os.path.join(pics_folder, f'{task_name}_*.png')))
#     192 if use_existing_pics and existing_pics:
#     193     print(f"Using existing pictures from {pics_folder}")
#
# NameError: name 'glob' is not defined
